# %%
# !pip install bitarray
# !pip install pyodbc
# !pip install hashlib
# Out:
# Collecting bitarray
#   Downloading bitarray-2.3.2.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 3.7 MB/s
# Building wheels for collected packages: bitarray
#   Building wheel for bitarray (setup.py) ... done
#   Created wheel for bitarray: filename=bitarray-2.3.2-cp37-cp37m-linux_x86_64.whl size=171921 sha256=adb633e815334aad787116912508c4e0888e6522df2ea53abbbdf701f6f33378
#   Stored in directory: /root/.cache/pip/wheels/02/3a/55/c4aba43815b20355bd5fc7219faae18315ae9f5bcd5393acf7
# Successfully built bitarray
# Installing collected packages: bitarray
# Successfully installed bitarray-2.3.2
# Collecting pyodbc
#   Downloading pyodbc-4.0.32.tar.gz (280 kB)
#      |████████████████████████████████| 280 kB 8.0 MB/s
# Building wheels for collected packages: pyodbc
#   Building wheel for pyodbc (setup.py) ... done
#   Created wheel for pyodbc: filename=pyodbc-4.0.32-cp37-cp37m-linux_x86_64.whl size=287378 sha256=caaff3351c520b4bc9f6a93b6d7749002652adc2f6350b99e626c4af6471ee1d
#   Stored in directory: /root/.cache/pip/wheels/2e/9c/da/8652fd42e0f662015554f00a9e96fe4f438dfd1ef59787879e
# Successfully built pyodbc
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.32
# Collecting hashlib
#   Downloading hashlib-20081119.zip (42 kB)
#      |████████████████████████████████| 42 kB 713 kB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/74/bb/9003d081345e9f0451884146e9ea2cff6e4cc4deac9ffd4a9ee98b318a49/hashlib-20081119.zip#sha256=419de2fd10ae71ed9c6adcb55903f116abd1d8acc8c814dfd5f839b4d5013e38 (from https://pypi.org/simple/hashlib/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement hashlib (from versions: 20081119)
# ERROR: No matching distribution found for hashlib

# %%
import math
import hashlib
import binascii
from bitarray import bitarray

# %% [markdown]
# # **BLOOM FILTER**

# %%
class BloomFilter(object):

	'''
	Class for Bloom filter, using SHA256 hash function
	'''

	def __init__(self, items_count, fp_prob):
		'''
    Bloom Filter is a bit of array of specified size (m) and initially sets to zero

    Glosarium:
		  n = items_count : int
			  Number of items expected to be stored in bloom filter
		  p = fp_prob : float
			  False Positive probability in decimal
      k = hash count
        Hash count needed for specified value. Formula commented alongside the function.
      m = size of array
        m CAN'T BE INPUTED MANUALLY without calculating the items count and hash count. Otherwise, collision increases.
		'''

		# Initialize false positive probability in decimal
		self.fp_prob = fp_prob

		# Initialize size (m) of bit array to use
		self.size = self.get_size(items_count, fp_prob)

		# Initialize number of hash functions (k) to use
		self.hash_count = self.get_hash_count(self.size, items_count)

		# Initialize bit array of given size
    # Creating the array that will use the bloom filter method
		self.bit_array = bitarray(self.size)

		# Initialize all bits as 0
		self.bit_array.setall(0)

	def add(self, item):
		'''
		Encode and insert an item into the filter
		'''
		digests = []
		for i in range(self.hash_count):

			# create digest for given item.
			# using SHA256
      # checking the bit value
      # set bit value = position mod m
			digest = int(hashlib.sha256(item.encode()).hexdigest(),16) % self.size
			digests.append(digest)

			# set the bit True in bit_array
			self.bit_array[digest] = True

	def check(self, item):
		'''
		Check for existence of an item in filter
		'''
		for i in range(self.hash_count):
			digest = int(hashlib.sha256(item.encode()).hexdigest(),16) % self.size
			if self.bit_array[digest] == False:

				# if any of bit is False then,its not present
				# in filter
				# else there is probability that it exist
				return False
		return True

	@classmethod
	def get_size(self, n, p):
		'''
		Return the size of bit array(m) to used using
		following formula
		m = -(n * lg(p)) / (lg(2)^2)
		n : int
			number of items expected to be stored in filter
		p : float
			False Positive probability in decimal
		'''
		m = -(n * math.log(p))/(math.log(2)**2)
		return int(m)

	@classmethod
	def get_hash_count(self, m, n):
		'''
		Return the hash function(k) to be used using
		following formula
		k = (m/n) * lg(2)

		m : int
			size of bit array
		n : int
			number of items expected to be stored in filter
		'''
		k = (m/n) * math.log(2)
		return int(k)

# %%
def create_list(array_count, element_count, fp_prob):
  '''
  Function to create multiple array that recall bloom filter method.
  '''
  array_bf = []
  a = array_count
  n = element_count
  p = fp_prob

  for i in range(a):
    BF = BloomFilter(n, p)
    array_bf.append(BF)

  return array_bf

# %% [markdown]
# Input Public Key

# %%
def insertPK(pk, indeks) : 
  code_pk = (bin(int(pk, 16))[2:])
  data.append([code_pk, indeks])

# %% [markdown]
# Pengecekan untuk panjang length (f + 1 bits)

# %%
def countLength(data):
  max = 0
  min = 0
  for i in range(len(data)) :
    if max == 0 :
      max = len(data[i][0])
    else :
      temp = len(data[i][0])
      if temp == max :
        max = temp
      elif temp < max :
        if temp == min or temp < min or temp > min:
          min = temp
      else :
        min = max 
        max = temp
  length = max
  return length

# %% [markdown]
# Penambahan '0' sehingga menjadi f+1 bits

# %%
def replacePK(max):
  for i in range(len(data)) :
    length = len(data[i][0])
    code_pk = data[i][0]
    if length < max :
      pk = code_pk
      count = max - length
      for j in range(count) :
        pk = pk + '0'
      data[i][0] = pk

# %% [markdown]
# # **TESTING**

# %% [markdown]
# 2 index dan 2 pk

# %%
# !pip3 install registry
# !pip install tinyec

import secrets
from tinyec import registry

def compress(pubKey):
    return hex(pubKey.x).lstrip('0x') + hex(pubKey.y % 2)[2:]

## Public key 1
curve1 = registry.get_curve('secp192r1')
PrivKey1 = secrets.randbelow(curve1.field.n)
PubKey1 = PrivKey1 * curve1.g
a = compress(PubKey1)

## Public key 2
curve = registry.get_curve('secp256r1')
PrivKey = secrets.randbelow(curve.field.n)
PubKey = PrivKey * curve.g
b = compress(PubKey)
# Out:
# Collecting registry
#   Downloading registry-0.4.2.zip (11 kB)
# Building wheels for collected packages: registry
#   Building wheel for registry (setup.py) ... done
#   Created wheel for registry: filename=registry-0.4.2-py3-none-any.whl size=6737 sha256=cf6099846d1a02045ab6f607d6554e08a03f00bad1a3c1b131c56584e261f322
#   Stored in directory: /root/.cache/pip/wheels/9d/2c/71/f7a7f77c1a7affb81f8551f59b33d73f0f68eceb9b05799d2b
# Successfully built registry
# Installing collected packages: registry
# Successfully installed registry-0.4.2
# Collecting tinyec
#   Downloading tinyec-0.3.1.tar.gz (23 kB)
# Building wheels for collected packages: tinyec
#   Building wheel for tinyec (setup.py) ... done
#   Created wheel for tinyec: filename=tinyec-0.3.1-py3-none-any.whl size=20781 sha256=9fafeee0059c1a0f8663a22e27d3f3a0175a255eabc7d84bc8ab2081357bb17b
#   Stored in directory: /root/.cache/pip/wheels/b9/a3/13/4abdd947dd381c96604852ed568dfc40dfe9afe28737a088c0
# Successfully built tinyec
# Installing collected packages: tinyec
# Successfully installed tinyec-0.3.1

# %%
data = []

insertPK(a, '10')
insertPK(b, '10')
insertPK(a, '12')
insertPK(b, '12')

n = 2 ## Banyaknya indeks tabel transaksi
p = 0.05

## Menentukan f+1
length = countLength(data)

## Penambahan '0' sepanjang length
replacePK(length)

## Membuat list bloom filter
list_bf = create_list(length, n, p)

# %%
length
# Out:
# 256

# %%
for row in range(len(data)) :
  count = 0
  pk = data[row][0]
  index = data[row][1]
  for i in pk :
    if i == '1' :
      list_bf[count].add(index)
    count += 1

# %%
data_test = ['10', '12']
for element in data_test:
  for i in range(len(list_bf)):
    if (list_bf[i].check(element) == True):
      print("'{}' is probably present in list number: ".format(element) + str(i))
# Out:
# '10' is probably present in list number: 0
# '10' is probably present in list number: 1
# '10' is probably present in list number: 4
# '10' is probably present in list number: 5
# '10' is probably present in list number: 7
# '10' is probably present in list number: 11
# '10' is probably present in list number: 14
# '10' is probably present in list number: 15
# '10' is probably present in list number: 17
# '10' is probably present in list number: 18
# '10' is probably present in list number: 19
# '10' is probably present in list number: 21
# '10' is probably present in list number: 23
# '10' is probably present in list number: 24
# '10' is probably present in list number: 25
# '10' is probably present in list number: 26
# '10' is probably present in list number: 27
# '10' is probably present in list number: 28
# '10' is probably present in list number: 30
# '10' is probably present in list number: 31
# '10' is probably present in list number: 39
# '10' is probably present in list number: 40
# '10' is probably present in list number: 41
# '10' is probably present in list number: 42
# '10' is probably present in list number: 43
# '10' is probably present in list number: 45
# '10' is probably present in list number: 48
# '10' is probably present in list number: 49
# '10' is probably present in list number: 50
# '10' is probably present in list number: 51
# '10' is probably present in list number: 52
# '10' is probably present in list number: 53
# '10' is probably present in list number: 54
# '10' is probably present in list number: 55
# '10' is probably present in list number: 56
# '10' is probably present in list number: 58
# '10' is probably present in list number: 59
# '10' is probably present in list number: 60
# '10' is probably present in list number: 61
# '10' is probably present in list number: 62
# '10' is probably present in list number: 63
# '10' is probably present in list number: 64
# '10' is probably present in list number: 65
# '10' is probably present in list number: 66
# '10' is probably present in list number: 69
# '10' is probably present in list number: 71
# '10' is probably present in list number: 72
# '10' is probably present in list number: 74
# '10' is probably present in list number: 76
# '10' is probably present in list number: 78
# '10' is probably present in list number: 80
# '10' is probably present in list number: 81
# '10' is probably present in list number: 83
# '10' is probably present in list number: 84
# '10' is probably present in list number: 89
# '10' is probably present in list number: 90
# '10' is probably present in list number: 92
# '10' is probably present in list number: 93
# '10' is probably present in list number: 95
# '10' is probably present in list number: 96
# '10' is probably present in list number: 98
# '10' is probably present in list number: 99
# '10' is probably present in list number: 100
# '10' is probably present in list number: 101
# '10' is probably present in list number: 102
# '10' is probably present in list number: 103
# '10' is probably present in list number: 105
# '10' is probably present in list number: 106
# '10' is probably present in list number: 107
# '10' is probably present in list number: 108
# '10' is probably present in list number: 109
# '10' is probably present in list number: 110
# '10' is probably present in list number: 111
# '10' is probably present in list number: 112
# '10' is probably present in list number: 113
# '10' is probably present in list number: 115
# '10' is probably present in list number: 116
# '10' is probably present in list number: 117
# '10' is probably present in list number: 119
# '10' is probably present in list number: 120
# '10' is probably present in list number: 121
# '10' is probably present in list number: 122
# '10' is probably present in list number: 123
# '10' is probably present in list number: 125
# '10' is probably present in list number: 126
# '10' is probably present in list number: 127
# '10' is probably present in list number: 130
# '10' is probably present in list number: 131
# '10' is probably present in list number: 132
# '10' is probably present in list number: 133
# '10' is probably present in list number: 134
# '10' is probably present in list number: 136
# '10' is probably present in list number: 137
# '10' is probably present in list number: 138
# '10' is probably present in list number: 140
# '10' is probably present in list number: 142
# '10' is probably present in list number: 144
# '10' is probably present in list number: 146
# '10' is probably present in list number: 147
# '10' is probably present in list number: 148
# '10' is probably present in list number: 149
# '10' is probably present in list number: 151
# '10' is probably present in list number: 153
# '10' is probably present in list number: 154
# '10' is probably present in list number: 155
# '10' is probably present in list number: 156
# '10' is probably present in list number: 157
# '10' is probably present in list number: 158
# '10' is probably present in list number: 159
# '10' is probably present in list number: 161
# '10' is probably present in list number: 162
# '10' is probably present in list number: 164
# '10' is probably present in list number: 165
# '10' is probably present in list number: 167
# '10' is probably present in list number: 168
# '10' is probably present in list number: 169
# '10' is probably present in list number: 170
# '10' is probably present in list number: 171
# '10' is probably present in list number: 172
# '10' is probably present in list number: 173
# '10' is probably present in list number: 174
# '10' is probably present in list number: 175
# '10' is probably present in list number: 177
# '10' is probably present in list number: 179
# '10' is probably present in list number: 181
# '10' is probably present in list number: 182
# '10' is probably present in list number: 183
# '10' is probably present in list number: 184
# '10' is probably present in list number: 185
# '10' is probably present in list number: 186
# '10' is probably present in list number: 187
# '10' is probably present in list number: 189
# '10' is probably present in list number: 192
# '10' is probably present in list number: 193
# '10' is probably present in list number: 194
# '10' is probably present in list number: 197
# '10' is probably present in list number: 199
# '10' is probably present in list number: 200
# '10' is probably present in list number: 201
# '10' is probably present in list number: 203
# '10' is probably present in list number: 206
# '10' is probably present in list number: 207
# '10' is probably present in list number: 208
# '10' is probably present in list number: 218
# '10' is probably present in list number: 220
# '10' is probably present in list number: 222
# '10' is probably present in list number: 225
# '10' is probably present in list number: 226
# '10' is probably present in list number: 229
# '10' is probably present in list number: 231
# '10' is probably present in list number: 235
# '10' is probably present in list number: 240
# '10' is probably present in list number: 241
# '10' is probably present in list number: 243
# '10' is probably present in list number: 246
# '10' is probably present in list number: 248
# '10' is probably present in list number: 250
# '10' is probably present in list number: 251
# '10' is probably present in list number: 254
# '12' is probably present in list number: 0
# '12' is probably present in list number: 1
# '12' is probably present in list number: 4
# '12' is probably present in list number: 5
# '12' is probably present in list number: 7
# '12' is probably present in list number: 11
# '12' is probably present in list number: 14
# '12' is probably present in list number: 15
# '12' is probably present in list number: 17
# '12' is probably present in list number: 18
# '12' is probably present in list number: 19
# '12' is probably present in list number: 21
# '12' is probably present in list number: 23
# '12' is probably present in list number: 24
# '12' is probably present in list number: 25
# '12' is probably present in list number: 26
# '12' is probably present in list number: 27
# '12' is probably present in list number: 28
# '12' is probably present in list number: 30
# '12' is probably present in list number: 31
# '12' is probably present in list number: 39
# '12' is probably present in list number: 40
# '12' is probably present in list number: 41
# '12' is probably present in list number: 42
# '12' is probably present in list number: 43
# '12' is probably present in list number: 45
# '12' is probably present in list number: 48
# '12' is probably present in list number: 49
# '12' is probably present in list number: 50
# '12' is probably present in list number: 51
# '12' is probably present in list number: 52
# '12' is probably present in list number: 53
# '12' is probably present in list number: 54
# '12' is probably present in list number: 55
# '12' is probably present in list number: 56
# '12' is probably present in list number: 58
# '12' is probably present in list number: 59
# '12' is probably present in list number: 60
# '12' is probably present in list number: 61
# '12' is probably present in list number: 62
# '12' is probably present in list number: 63
# '12' is probably present in list number: 64
# '12' is probably present in list number: 65
# '12' is probably present in list number: 66
# '12' is probably present in list number: 69
# '12' is probably present in list number: 71
# '12' is probably present in list number: 72
# '12' is probably present in list number: 74
# '12' is probably present in list number: 76
# '12' is probably present in list number: 78
# '12' is probably present in list number: 80
# '12' is probably present in list number: 81
# '12' is probably present in list number: 83
# '12' is probably present in list number: 84
# '12' is probably present in list number: 89
# '12' is probably present in list number: 90
# '12' is probably present in list number: 92
# '12' is probably present in list number: 93
# '12' is probably present in list number: 95
# '12' is probably present in list number: 96
# '12' is probably present in list number: 98
# '12' is probably present in list number: 99
# '12' is probably present in list number: 100
# '12' is probably present in list number: 101
# '12' is probably present in list number: 102
# '12' is probably present in list number: 103
# '12' is probably present in list number: 105
# '12' is probably present in list number: 106
# '12' is probably present in list number: 107
# '12' is probably present in list number: 108
# '12' is probably present in list number: 109
# '12' is probably present in list number: 110
# '12' is probably present in list number: 111
# '12' is probably present in list number: 112
# '12' is probably present in list number: 113
# '12' is probably present in list number: 115
# '12' is probably present in list number: 116
# '12' is probably present in list number: 117
# '12' is probably present in list number: 119
# '12' is probably present in list number: 120
# '12' is probably present in list number: 121
# '12' is probably present in list number: 122
# '12' is probably present in list number: 123
# '12' is probably present in list number: 125
# '12' is probably present in list number: 126
# '12' is probably present in list number: 127
# '12' is probably present in list number: 130
# '12' is probably present in list number: 131
# '12' is probably present in list number: 132
# '12' is probably present in list number: 133
# '12' is probably present in list number: 134
# '12' is probably present in list number: 136
# '12' is probably present in list number: 137
# '12' is probably present in list number: 138
# '12' is probably present in list number: 140
# '12' is probably present in list number: 142
# '12' is probably present in list number: 144
# '12' is probably present in list number: 146
# '12' is probably present in list number: 147
# '12' is probably present in list number: 148
# '12' is probably present in list number: 149
# '12' is probably present in list number: 151
# '12' is probably present in list number: 153
# '12' is probably present in list number: 154
# '12' is probably present in list number: 155
# '12' is probably present in list number: 156
# '12' is probably present in list number: 157
# '12' is probably present in list number: 158
# '12' is probably present in list number: 159
# '12' is probably present in list number: 161
# '12' is probably present in list number: 162
# '12' is probably present in list number: 164
# '12' is probably present in list number: 165
# '12' is probably present in list number: 167
# '12' is probably present in list number: 168
# '12' is probably present in list number: 169
# '12' is probably present in list number: 170
# '12' is probably present in list number: 171
# '12' is probably present in list number: 172
# '12' is probably present in list number: 173
# '12' is probably present in list number: 174
# '12' is probably present in list number: 175
# '12' is probably present in list number: 177
# '12' is probably present in list number: 179
# '12' is probably present in list number: 181
# '12' is probably present in list number: 182
# '12' is probably present in list number: 183
# '12' is probably present in list number: 184
# '12' is probably present in list number: 185
# '12' is probably present in list number: 186
# '12' is probably present in list number: 187
# '12' is probably present in list number: 189
# '12' is probably present in list number: 192
# '12' is probably present in list number: 193
# '12' is probably present in list number: 194
# '12' is probably present in list number: 197
# '12' is probably present in list number: 199
# '12' is probably present in list number: 200
# '12' is probably present in list number: 201
# '12' is probably present in list number: 203
# '12' is probably present in list number: 206
# '12' is probably present in list number: 207
# '12' is probably present in list number: 208
# '12' is probably present in list number: 218
# '12' is probably present in list number: 220
# '12' is probably present in list number: 222
# '12' is probably present in list number: 225
# '12' is probably present in list number: 226
# '12' is probably present in list number: 229
# '12' is probably present in list number: 231
# '12' is probably present in list number: 235
# '12' is probably present in list number: 240
# '12' is probably present in list number: 241
# '12' is probably present in list number: 243
# '12' is probably present in list number: 246
# '12' is probably present in list number: 248
# '12' is probably present in list number: 250
# '12' is probably present in list number: 251
# '12' is probably present in list number: 254
